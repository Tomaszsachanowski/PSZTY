# %% [markdown]
# # Import pobrzebnych funkcji do irisow

# %%
import numpy as np
from sklearn import datasets
from sklearn.decomposition import PCA

# %% [markdown]
# # Stworzenie zbiru irisow

# %%
iris = datasets.load_iris()

# %% [markdown]
# # Bibiloteka do rysowania

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook

# import some data to play with
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(3, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())



X = iris.data[:, 2:]  # we only take the first two features.
y = iris.target

x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')


plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())


fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(X_reduced[:50, 0], X_reduced[:50, 1], X_reduced[:50, 2], c='g',
            s=10)
ax.scatter(X_reduced[50:100, 0], X_reduced[50:100, 1], X_reduced[50:100, 2], c='y',
            s=10)
ax.scatter(X_reduced[100:, 0], X_reduced[100:, 1], X_reduced[100:, 2], c='r',
            s=10)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">
# <img src="data:image/png;base64,..." width="799.3333333333334">
# <img src="data:image/png;base64,..." width="799.3333333333334">
# []

# %% [markdown]
# # Import naszej funkcji ktora łączy dwa wybrane zbiory 0,1,2

# %%
from generujDane import iris_two_collection

# %% [markdown]
# # X- zbior naszych danych do klasyfikacji binarnej

# %%
X = iris_two_collection(iris, 0, 1)

# %%
X
# Out:
# array([[-2.68412563,  0.31939725, -0.02791483,  1.        ],
#        [-2.71414169, -0.17700123, -0.21046427,  1.        ],
#        [-2.88899057, -0.14494943,  0.01790026,  1.        ],
#        [-2.74534286, -0.31829898,  0.03155937,  1.        ],
#        [-2.72871654,  0.32675451,  0.09007924,  1.        ],
#        [-2.28085963,  0.74133045,  0.16867766,  1.        ],
#        [-2.82053775, -0.08946138,  0.25789216,  1.        ],
#        [-2.62614497,  0.16338496, -0.02187932,  1.        ],
#        [-2.88638273, -0.57831175,  0.02075957,  1.        ],
#        [-2.6727558 , -0.11377425, -0.19763272,  1.        ],
#        [-2.50694709,  0.6450689 , -0.07531801,  1.        ],
#        [-2.61275523,  0.01472994,  0.10215026,  1.        ],
#        [-2.78610927, -0.235112  , -0.20684443,  1.        ],
#        [-3.22380374, -0.51139459,  0.06129967,  1.        ],
#        [-2.64475039,  1.17876464, -0.15162752,  1.        ],
# ...

# %% [markdown]
# # Wyświetlenie naszego zbioru binarnego w dwoch rzutach i 3D

# %%
# %matplotlib notebook

# import some data to play with


plt.figure(3, figsize=(8, 6))
plt.clf()

# Plot the training points
for point in X:
    if point[-1] == 1:
        plt.scatter(point[0], point[1], c='b')
    else:
        plt.scatter(point[0], point[1], c='g')

plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())


plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
for point in X:
    if point[-1] == 1:
        plt.scatter(point[0], point[2], c='b')
    else:
        plt.scatter(point[0], point[2], c='g')



x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
y_min, y_max = X[:,2].min() - .5, X[:,2].max() + .5
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())




fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
for point in X:
        if point[-1] == 1:
            ax.scatter(point[0], point[1], point[2], c='b', s=10)
        else:
            ax.scatter(point[0], point[1], point[2], c='g', s=10)
            
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">
# <img src="data:image/png;base64,..." width="799.3333333333334">
# <img src="data:image/png;base64,..." width="799.3333333333334">
# []

# %% [markdown]
# # Zainicjowanie algorytmu ewolucyjnego

# %%
from populacja import Populacja

# %% [markdown]
# # stworzenie populacji początkowej
# ## lambda = 30
# ## mi = 10
# ## prawdopodobieństwo mutacji = 0.2

# %%
pop = Populacja(30, 10, 0.2, X)

# %% [markdown]
# # osobnicy początkowi

# %%
for os in pop.populacja_P:
    print(os.wektor_wspol_w)
# Out:
# [-0.58587909 -1.74241471  1.43384938  0.33606455]
# [-0.4338161  -0.38803761 -1.2545921   1.04451908]
# [-0.09304148 -1.67754066  1.27665185  1.88017252]
# [-0.05870354 -1.91728626 -0.96422943  1.87143099]
# [ 0.46380673  1.17931549  0.29764329 -0.16256311]
# [-0.72355576  0.89382244  0.36780867  0.94471809]
# [-0.82711935  1.25251508  0.82191304  1.09180745]
# [-0.82462629  1.09239301 -1.91132744 -1.24612601]
# [ 0.40466252 -0.45058667 -1.57078006 -0.38511636]
# [1.93203079 0.79392198 0.42833894 0.2187432 ]

# %% [markdown]
# # Wyświetlenie naszych płaszczyn

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D





xx, yy = np.meshgrid(range(-3,3,1), range(-3,3,1))
plt3d = plt.figure().gca(projection='3d')

# calculate corresponding z
for os in pop.populacja_P:
    d = os.wektor_wspol_w[0]
    a = os.wektor_wspol_w[1]
    b = os.wektor_wspol_w[2]
    c = os.wektor_wspol_w[3]
    z = (-a * xx - b * yy - d) * 1. / c

    # plot the surface
    # plot the surface
    plt3d.plot_surface(xx, yy, z, alpha=0.2)

for point in X:
        if point[-1] == 1:
            plt3d.scatter(point[0], point[1], point[2], c='b', s=10)
        else:
            plt3d.scatter(point[0], point[1], point[2], c='g', s=10)
            
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# []

# %% [markdown]
# # Selecja osobnikow(wykonanie 50 iteracji)

# %%
for i in range(0,50,1):
    pop.krzyzowanie_interpolacja()
    pop.selekcja_loss_1()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D





xx, yy = np.meshgrid(range(-3,3,1), range(-3,3,1))
plt3d = plt.figure().gca(projection='3d')

# calculate corresponding z
for os in pop.populacja_P:
    d = os.wektor_wspol_w[0]
    a = os.wektor_wspol_w[1]
    b = os.wektor_wspol_w[2]
    c = os.wektor_wspol_w[3]
    z = (-a * xx - b * yy - d) * 1. / c

    # plot the surface
    # plot the surface
    plt3d.plot_surface(xx, yy, z, alpha=0.2)

for point in X:
        if point[-1] == 1:
            plt3d.scatter(point[0], point[1], point[2], c='b', s=10)
        else:
            plt3d.scatter(point[0], point[1], point[2], c='g', s=10)
            
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# []

# %% [markdown]
# # Zmiana zbiorow

# %%
X = iris_two_collection(iris, 1, 2)

# %%
X
# Out:
# array([[-2.68412563,  0.31939725, -0.02791483,  1.        ],
#        [-2.71414169, -0.17700123, -0.21046427,  1.        ],
#        [-2.88899057, -0.14494943,  0.01790026,  1.        ],
#        [-2.74534286, -0.31829898,  0.03155937,  1.        ],
#        [-2.72871654,  0.32675451,  0.09007924,  1.        ],
#        [-2.28085963,  0.74133045,  0.16867766,  1.        ],
#        [-2.82053775, -0.08946138,  0.25789216,  1.        ],
#        [-2.62614497,  0.16338496, -0.02187932,  1.        ],
#        [-2.88638273, -0.57831175,  0.02075957,  1.        ],
#        [-2.6727558 , -0.11377425, -0.19763272,  1.        ],
#        [-2.50694709,  0.6450689 , -0.07531801,  1.        ],
#        [-2.61275523,  0.01472994,  0.10215026,  1.        ],
#        [-2.78610927, -0.235112  , -0.20684443,  1.        ],
#        [-3.22380374, -0.51139459,  0.06129967,  1.        ],
#        [-2.64475039,  1.17876464, -0.15162752,  1.        ],
# ...

# %%
# %matplotlib notebook

# import some data to play with


plt.figure(3, figsize=(8, 6))
plt.clf()

# Plot the training points
for point in X:
    if point[-1] == 1:
        plt.scatter(point[0], point[1], c='b')
    else:
        plt.scatter(point[0], point[1], c='g')

plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())


plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
for point in X:
    if point[-1] == 1:
        plt.scatter(point[0], point[2], c='b')
    else:
        plt.scatter(point[0], point[2], c='g')



plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())




fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
for point in X:
        if point[-1] == 1:
            ax.scatter(point[0], point[1], point[2], c='b', s=10)
        else:
            ax.scatter(point[0], point[1], point[2], c='g', s=10)
            
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">
# <img src="data:image/png;base64,..." width="799.3333333333334">
# <img src="data:image/png;base64,..." width="799.3333333333334">
# []

# %%
pop = Populacja(40, 20, 0.4, X)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D





xx, yy = np.meshgrid(range(-3,3,1), range(-3,3,1))
plt3d = plt.figure().gca(projection='3d')

# calculate corresponding z
for os in pop.populacja_P:
    d = os.wektor_wspol_w[0]
    a = os.wektor_wspol_w[1]
    b = os.wektor_wspol_w[2]
    c = os.wektor_wspol_w[3]
    z = (-a * xx - b * yy - d) * 1. / c

    # plot the surface
    # plot the surface
    plt3d.plot_surface(xx, yy, z, alpha=0.2)

for point in X:
        if point[-1] == 1:
            plt3d.scatter(point[0], point[1], point[2], c='b', s=10)
        else:
            plt3d.scatter(point[0], point[1], point[2], c='g', s=10)
            
plt3d.set_title("First three PCA directions")
plt3d.set_xlabel("1st eigenvector")
plt3d.w_xaxis.set_ticklabels([])
plt3d.set_ylabel("2nd eigenvector")
plt3d.w_yaxis.set_ticklabels([])
plt3d.set_zlabel("3rd eigenvector")
plt3d.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# []

# %%
for i in range(0,80,1):
    pop.krzyzowanie()
    pop.selekcja_loss_2()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D





xx, yy = np.meshgrid(range(-3,3,1), range(-3,3,1))
plt3d = plt.figure().gca(projection='3d')

# calculate corresponding z
for os in pop.populacja_P:
    d = os.wektor_wspol_w[0]
    a = os.wektor_wspol_w[1]
    b = os.wektor_wspol_w[2]
    c = os.wektor_wspol_w[3]
    z = (-a * xx - b * yy - d) * 1. / c

    # plot the surface
    # plot the surface
    plt3d.plot_surface(xx, yy, z, alpha=0.2)

for point in X:
        if point[-1] == 1:
            plt3d.scatter(point[0], point[1], point[2], c='b', s=10)
        else:
            plt3d.scatter(point[0], point[1], point[2], c='g', s=10)
            
plt3d.set_title("First three PCA directions")
plt3d.set_xlabel("1st eigenvector")
plt3d.w_xaxis.set_ticklabels([])
plt3d.set_ylabel("2nd eigenvector")
plt3d.w_yaxis.set_ticklabels([])
plt3d.set_zlabel("3rd eigenvector")
plt3d.w_zaxis.set_ticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# []
